# %%
import pandas as pd

# %%
pib = pd.read_csv('PIB.csv')
pib.head()
# Out:
#   PIB\nPosición          Estado  PIB\n($ Millones)  \
# 0           NaN  Estados Unidos          14657.800
# 1             1      California           1936.400
# 2             2           Texas           1207.432
# 3             3      Nueva York           1156.500
# 4             4         Florida            754.000
#
#    Porcentaje del\nPIB Nacional  Población\n(Millones)  PIB\nper cápita ($)  \
# 0                        100.00                  308.7               47.482
# 1                         13.34                   37.3               51.914
# 2                          7.95                   25.1               45.940
# 3                          7.68                   19.4               57.423
# 4                          5.20                   18.8               40.106
#
#    PIB per cápita\nPosición
# 0                       NaN
# 1                      12.0
# 2                      24.0
# 3                       7.0
# 4                      40.0

# %%
desempleo = pd.read_csv('Desempleo.csv')
desempleo.head(5)
# Out:
#   Rank Rank\n(50 states)          State\nfederal district\nor territory  \
# 0    1                 —                                 American Samoa
# 1    —                 —  Northern Mariana Islands[6]: 60, 66, 103, 109
# 2    2                 —                                 Puerto Rico[7]
# 3    3                 1                                         Nevada
# 4    3                 1                                     California
#
#    Unemployment rate \n Monthly change (%)\n(=drop in unemployment)
# 0                 0.114                                           —
# 1                 0.112                                           —
# 2                 0.083                                         0.1
# 3                 0.075                                         0.2
# 4                 0.075                                           0

# %%
desempleo["Unemployment rate \n"] < 2008
mayor = desem[planets['year'] == 2008]
